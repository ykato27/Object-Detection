# %% [markdown]
# <a href="https://colab.research.google.com/github/ykato27/Object-Detection/blob/main/NanoDet_Colaboratory_Training_Sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PyTorch Lightningインストール(PyTorch Lightning install)

# %%
# !pip install pytorch_lightning
# Out:
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-1.5.3-py3-none-any.whl (523 kB)
#      |████████████████████████████████| 523 kB 4.1 MB/s
# Collecting torchmetrics>=0.4.1
#   Downloading torchmetrics-0.6.0-py3-none-any.whl (329 kB)
#      |████████████████████████████████| 329 kB 36.4 MB/s
# Collecting pyDeprecate==0.3.1
#   Downloading pyDeprecate-0.3.1-py3-none-any.whl (10 kB)
# Collecting PyYAML>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 35.4 MB/s
# Collecting future>=0.17.1
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 41.7 MB/s
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (2.7.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (3.10.0.2)
# Requirement already satisfied: torch>=1.6 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (1.10.0+cu111)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (21.3)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2021.11.0-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 44.7 MB/s
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (1.19.5)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (4.62.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (2.23.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 41.0 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=17.0->pytorch_lightning) (3.0.6)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (0.12.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.42.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.8.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (57.4.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.0.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (0.37.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (3.3.6)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (3.17.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (0.6.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.4->tensorboard>=2.2.0->pytorch_lightning) (1.15.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch_lightning) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch_lightning) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch_lightning) (3.1.1)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (160 kB)
#      |████████████████████████████████| 160 kB 47.2 MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 49.1 MB/s
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (192 kB)
#      |████████████████████████████████| 192 kB 52.8 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.1-py3-none-any.whl (5.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (21.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (2.0.7)
# Building wheels for collected packages: future
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=a4a180ded0efa1b6f9042fda005a29e074369b804de485296b3c3fb58379d08f
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
# Successfully built future
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, fsspec, aiohttp, torchmetrics, PyYAML, pyDeprecate, future, pytorch-lightning
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: future
#     Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
# Successfully installed PyYAML-6.0 aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.1 asynctest-0.13.0 frozenlist-1.2.0 fsspec-2021.11.0 future-0.18.2 multidict-5.2.0 pyDeprecate-0.3.1 pytorch-lightning-1.5.3 torchmetrics-0.6.0 yarl-1.7.2

# %% [markdown]
# # 乱数シード固定(Random seed fixed)

# %%
import os
import random

import torch
import numpy as np
import glob
import shutil

def initialize_random_seed(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

# %%
initialize_random_seed(42)

# %% [markdown]
# # データセットダウンロード(Download Dataset)

# %%
use_sample_image = True

if use_sample_image:
    # !git clone https://github.com/Kazuhito00/NanoDet-Colaboratory-Training-Sample.git
# Out:
# Cloning into 'NanoDet-Colaboratory-Training-Sample'...
# remote: Enumerating objects: 195, done.
# remote: Counting objects: 100% (195/195), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 195 (delta 68), reused 169 (delta 54), pack-reused 0
# Receiving objects: 100% (195/195), 29.95 MiB | 14.17 MiB/s, done.
# Resolving deltas: 100% (68/68), done.

# %%
# 独自のデータを使用する場合は、パスを指定してください
# Please fill in the path if you want to use your own data
if use_sample_image:
    dataset_directory = 'NanoDet-Colaboratory-Training-Sample/02.annotation_data'
else:
    dataset_directory = ''

# 学習/検証データパス
train_directory = './train'
validation_directory = './validation'

# 学習データ格納ディレクトリ作成(Create training data storage directory)
for dir_path in os.listdir(dataset_directory):
    os.makedirs(train_directory + '/' + dir_path, exist_ok=True)
# 検証データ格納ディレクトリ作成(Create verification data storage directory)
for dir_path in os.listdir(dataset_directory):
    os.makedirs(validation_directory + '/' + dir_path, exist_ok=True)

# %%
# 学習データの割合(Percentage of training data)
train_ratio = 0.8

# コピー元ファイルリスト取得(Get copy source file list)
annotation_list = sorted(glob.glob(dataset_directory + '/Annotations/*'))
image_list = sorted(glob.glob(dataset_directory + '/JPEGImages/*'))

file_num = len(annotation_list)

# インデックスシャッフル(shuffle)
index_list = list(range(file_num - 1))
random.shuffle(index_list)

for count, index in enumerate(index_list):
    if count < int(file_num * train_ratio):
        # 学習用データ(Training Data)
        shutil.copy2(annotation_list[index], train_directory + '/Annotations')
        shutil.copy2(image_list[index], train_directory + '/JPEGImages')
    else:
        # 検証用データ(Validation Data)
        shutil.copy2(annotation_list[index], validation_directory + '/Annotations')
        shutil.copy2(image_list[index], validation_directory + '/JPEGImages')

# %% [markdown]
# # Pascal VOC形式 を MS COCO形式へ変換

# %%
# !git clone https://github.com/Kazuhito00/voc2coco.git
# Out:
# Cloning into 'voc2coco'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 53 (delta 0), reused 1 (delta 0), pack-reused 50
# Unpacking objects: 100% (53/53), done.

# %%
# !python voc2coco/voc2coco.py train/Annotations train/annotations.json
# !python voc2coco/voc2coco.py validation/Annotations validation/annotations.json
# Out:
# Number of xml files: 40
# Success: train/annotations.json
# Number of xml files: 9
# Success: validation/annotations.json

# %% [markdown]
# # モデル訓練(Training Model)

# %%
# !git clone https://github.com/RangiLyu/nanodet.git
# !cp NanoDet-Colaboratory-Training-Sample/03.config/nanodet-m.yml nanodet/nanodet-m.yml
# Out:
# Cloning into 'nanodet'...
# remote: Enumerating objects: 2271, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 2271 (delta 34), reused 71 (delta 24), pack-reused 2162
# Receiving objects: 100% (2271/2271), 5.27 MiB | 15.78 MiB/s, done.
# Resolving deltas: 100% (1281/1281), done.

# %%
# %cd nanodet
# !cp tools/train.py ./
# Out:
# /content/nanodet

# %% [markdown]
# 「nanodet-m.yml」を格納してください(Store "nanodet-m.yml")<br><br>
# ![image](https://user-images.githubusercontent.com/37477845/133949475-e6aefaab-fbcd-41fd-a059-b99999bbe5a3.png)

# %%
# 訓練(Training)
# !python train.py nanodet-m.yml
# Out:
# [NanoDet][11-26 00:09:51]INFO:Setting up data...
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [NanoDet][11-26 00:09:51]INFO:Creating model...
# model size is  1.0x
# init weights...
# Downloading: "https://download.pytorch.org/models/shufflenetv2_x1-5666bf0f80.pth" to /root/.cache/torch/hub/checkpoints/shufflenetv2_x1-5666bf0f80.pth
# 100% 8.79M/8.79M [00:00<00:00, 64.0MB/s]
# => loading pretrained model https://download.pytorch.org/models/shufflenetv2_x1-5666bf0f80.pth
# Finish initialize NanoDet Head.
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/callbacks/progress/progress.py:22: LightningDeprecationWarning: `ProgressBar` has been deprecated in v1.5 and will be removed in v1.7. It has been renamed to `TQDMProgressBar` instead.
#   "`ProgressBar` has been deprecated in v1.5 and will be removed in v1.7."
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:287: LightningDeprecationWarning: Passing `Trainer(accelerator='ddp')` has been deprecated in v1.5 and will be removed in v1.7. Use `Trainer(strategy='ddp')` instead.
#   f"Passing `Trainer(accelerator={self.distributed_backend!r})` has been deprecated"
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/configuration_validator.py:140: LightningDeprecationWarning: The `LightningModule.get_progress_bar_dict` method was deprecated in v1.5 and will be removed in v1.7. Please use the `ProgressBarBase.get_metrics` instead.
#   "The `LightningModule.get_progress_bar_dict` method was deprecated in v1.5 and will be removed in v1.7."
# initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [NanoDet][11-26 00:10:01]INFO:hyperparams:
#
#   | Name  | Type             | Params
# -------------------------------------------
# 0 | model | OneStageDetector | 936 K
# -------------------------------------------
# 936 K     Trainable params
# 0         Non-trainable params
# 936 K     Total params
# 3.745     Total estimated model params size (MB)
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/data_loading.py:408: UserWarning: The number of training samples (1) is smaller than the logging interval Trainer(log_every_n_steps=10). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   f"The number of training samples ({self.num_training_batches}) is smaller than the logging interval"
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3635: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode)
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3680: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [NanoDet][11-26 00:10:07]INFO:Train|Epoch1/280|Iter0(0)| lr:1.40e-02| loss_qfl:0.1400| loss_bbox:1.5382| loss_dfl:0.5228|
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3635: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode)
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3680: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# [NanoDet][11-26 00:10:20]INFO:Val|Epoch10/280|Iter9(0)| lr:1.78e-02| loss_qfl:0.1621| loss_bbox:1.4921| loss_dfl:0.5172|
# /content/nanodet/nanodet/evaluator/coco_detection.py:71: UserWarning: Detection result is empty! Please check whether training set is too small (need to increase val_interval in config and train more epochs). Or check annotation correctness.
#   "Detection result is empty! Please check whether "
# [NanoDet][11-26 00:10:21]INFO:Val_metrics: {'mAP': 0, 'AP_50': 0, 'AP_75': 0, 'AP_small': 0, 'AP_m': 0, 'AP_l': 0}
# [NanoDet][11-26 00:10:22]INFO:Train|Epoch11/280|Iter10(0)| lr:1.82e-02| loss_qfl:0.1446| loss_bbox:1.0052| loss_dfl:0.4073|
# [NanoDet][11-26 00:10:34]INFO:Val|Epoch20/280|Iter19(0)| lr:2.20e-02| loss_qfl:0.1663| loss_bbox:1.4816| loss_dfl:0.5136|
# /content/nanodet/nanodet/trainer/task.py:164: UserWarning: Warning! Save_key is not in eval results! Only save model last!
#   "Warning! Save_key is not in eval results! Only save model last!"
# [NanoDet][11-26 00:10:34]INFO:Val_metrics: {'mAP': 0, 'AP_50': 0, 'AP_75': 0, 'AP_small': 0, 'AP_m': 0, 'AP_l': 0}
# [NanoDet][11-26 00:10:36]INFO:Train|Epoch21/280|Iter20(0)| lr:2.24e-02| loss_qfl:0.1317| loss_bbox:0.9363| loss_dfl:0.3457|
# [NanoDet][11-26 00:10:48]INFO:Val|Epoch30/280|Iter29(0)| lr:2.62e-02| loss_qfl:0.1814| loss_bbox:1.4437| loss_dfl:0.4985|
# [NanoDet][11-26 00:10:48]INFO:Val_metrics: {'mAP': 0, 'AP_50': 0, 'AP_75': 0, 'AP_small': 0, 'AP_m': 0, 'AP_l': 0}
# [NanoDet][11-26 00:10:49]INFO:Train|Epoch31/280|Iter30(0)| lr:2.66e-02| loss_qfl:0.1214| loss_bbox:0.8218| loss_dfl:0.3074|
# [NanoDet][11-26 00:11:02]INFO:Val|Epoch40/280|Iter39(0)| lr:3.04e-02| loss_qfl:0.3670| loss_bbox:1.0200| loss_dfl:0.3785|
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.121
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.400
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.031
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.051
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.208
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.070
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.155
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.155
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.269
# [NanoDet][11-26 00:11:02]INFO:Val_metrics: {'mAP': 0.12094169938734331, 'AP_50': 0.3998471170646477, 'AP_75': 0.031042953919452096, 'AP_small': 0.0, 'AP_m': 0.05148514851485148, 'AP_l': 0.20784910263727355}
# [NanoDet][11-26 00:11:03]INFO:Train|Epoch41/280|Iter40(0)| lr:3.08e-02| loss_qfl:0.1391| loss_bbox:0.6791| loss_dfl:0.2758|
# [NanoDet][11-26 00:11:16]INFO:Val|Epoch50/280|Iter49(0)| lr:3.46e-02| loss_qfl:0.2525| loss_bbox:0.6920| loss_dfl:0.2866|
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.10s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.275
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.728
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.087
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.264
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.354
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.085
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.372
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.394
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.352
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.465
# [NanoDet][11-26 00:11:16]INFO:Val_metrics: {'mAP': 0.2750230664407903, 'AP_50': 0.7275428877176681, 'AP_75': 0.08728393474555003, 'AP_small': 0.0, 'AP_m': 0.26372309336029875, 'AP_l': 0.3541399193639812}
# [NanoDet][11-26 00:11:17]INFO:Train|Epoch51/280|Iter50(0)| lr:3.50e-02| loss_qfl:0.1352| loss_bbox:0.6163| loss_dfl:0.2466|
# [NanoDet][11-26 00:11:30]INFO:Val|Epoch60/280|Iter59(0)| lr:3.88e-02| loss_qfl:0.2006| loss_bbox:0.6255| loss_dfl:0.2630|
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.14s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.354
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.804
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.203
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.312
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.439
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.100
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.440
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.485
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.448
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.558
# [NanoDet][11-26 00:11:30]INFO:Val_metrics: {'mAP': 0.35359634933782463, 'AP_50': 0.8036856435064641, 'AP_75': 0.20340622866154973, 'AP_small': 0.0, 'AP_m': 0.3123887530781927, 'AP_l': 0.4392234942903368}
# [NanoDet][11-26 00:11:31]INFO:Train|Epoch61/280|Iter60(0)| lr:3.92e-02| loss_qfl:0.1532| loss_bbox:0.5680| loss_dfl:0.2410|
# [NanoDet][11-26 00:11:44]INFO:Val|Epoch70/280|Iter69(0)| lr:4.30e-02| loss_qfl:0.2911| loss_bbox:0.5912| loss_dfl:0.2561|
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.17s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.369
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.848
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.198
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.332
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.451
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.094
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.443
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.523
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.500
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.585
# [NanoDet][11-26 00:11:44]INFO:Val_metrics: {'mAP': 0.3687226044644207, 'AP_50': 0.8482562060666488, 'AP_75': 0.1979001169484138, 'AP_small': 0.0, 'AP_m': 0.3319916955116985, 'AP_l': 0.450820815237581}
# [NanoDet][11-26 00:11:45]INFO:Train|Epoch71/280|Iter70(0)| lr:4.34e-02| loss_qfl:0.1609| loss_bbox:0.5751| loss_dfl:0.2339|
# [NanoDet][11-26 00:11:58]INFO:Val|Epoch80/280|Iter79(0)| lr:4.72e-02| loss_qfl:0.1843| loss_bbox:0.5955| loss_dfl:0.2430|
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.17s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.407
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.909
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.252
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.381
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.482
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.092
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.487
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.528
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.504
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.592
# [NanoDet][11-26 00:11:58]INFO:Val_metrics: {'mAP': 0.4073105930817399, 'AP_50': 0.9091089305199999, 'AP_75': 0.25163985060758637, 'AP_small': 0.0, 'AP_m': 0.3814207535419945, 'AP_l': 0.48154316712073897}
# [NanoDet][11-26 00:12:00]INFO:Train|Epoch81/280|Iter80(0)| lr:4.76e-02| loss_qfl:0.1702| loss_bbox:0.5409| loss_dfl:0.2184|
# [NanoDet][11-26 00:12:12]INFO:Val|Epoch90/280|Iter89(0)| lr:5.14e-02| loss_qfl:0.2484| loss_bbox:0.5941| loss_dfl:0.2459|
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.17s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.406
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.919
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.327
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.373
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.492
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.089
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.491
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.517
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.440
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.631
# [NanoDet][11-26 00:12:12]INFO:Val_metrics: {'mAP': 0.4060966162961787, 'AP_50': 0.9189595121262109, 'AP_75': 0.32731481402409696, 'AP_small': 0.0, 'AP_m': 0.3727025221678083, 'AP_l': 0.49210365841873166}
# [NanoDet][11-26 00:12:14]INFO:Train|Epoch91/280|Iter90(0)| lr:5.18e-02| loss_qfl:0.1442| loss_bbox:0.5077| loss_dfl:0.2170|
# [NanoDet][11-26 00:12:26]INFO:Val|Epoch100/280|Iter99(0)| lr:5.56e-02| loss_qfl:0.3037| loss_bbox:0.5818| loss_dfl:0.2471|
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.17s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.391
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.878
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.209
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.379
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.466
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.092
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.455
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.481
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.440
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.558
# [NanoDet][11-26 00:12:26]INFO:Val_metrics: {'mAP': 0.39074620692880285, 'AP_50': 0.8782040329213091, 'AP_75': 0.20893585682235555, 'AP_small': 0.0, 'AP_m': 0.37880240453427283, 'AP_l': 0.466179479128969}
# [NanoDet][11-26 00:12:27]INFO:Train|Epoch101/280|Iter100(0)| lr:5.60e-02| loss_qfl:0.1347| loss_bbox:0.4909| loss_dfl:0.2048|
# [NanoDet][11-26 00:12:40]INFO:Val|Epoch110/280|Iter109(0)| lr:5.98e-02| loss_qfl:0.4473| loss_bbox:0.5345| loss_dfl:0.2284|
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.17s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.452
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.904
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.342
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.398
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.556
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.106
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.517
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.540
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.464
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.654
# [NanoDet][11-26 00:12:40]INFO:Val_metrics: {'mAP': 0.4517183734997333, 'AP_50': 0.9044986984745202, 'AP_75': 0.3423985656521306, 'AP_small': 0.0, 'AP_m': 0.3982670595227479, 'AP_l': 0.5556813879822362}
# [NanoDet][11-26 00:12:42]INFO:Train|Epoch111/280|Iter110(0)| lr:6.02e-02| loss_qfl:0.1729| loss_bbox:0.4962| loss_dfl:0.2045|
# [NanoDet][11-26 00:12:54]INFO:Val|Epoch120/280|Iter119(0)| lr:6.40e-02| loss_qfl:0.3089| loss_bbox:0.5441| loss_dfl:0.2223|
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.18s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.455
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.914
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.371
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.364
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.586
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.113
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.513
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.519
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.436
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.638
# [NanoDet][11-26 00:12:55]INFO:Val_metrics: {'mAP': 0.45484620006231796, 'AP_50': 0.914321500911988, 'AP_75': 0.3705560665083088, 'AP_small': 0.0, 'AP_m': 0.3643926519559497, 'AP_l': 0.5862385980356277}
# [NanoDet][11-26 00:12:56]INFO:Train|Epoch121/280|Iter120(0)| lr:6.44e-02| loss_qfl:0.1631| loss_bbox:0.4614| loss_dfl:0.2054|
# [NanoDet][11-26 00:13:08]INFO:Val|Epoch130/280|Iter129(0)| lr:6.82e-02| loss_qfl:0.4823| loss_bbox:0.5132| loss_dfl:0.2174|
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.17s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.459
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.919
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.415
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.391
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.580
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.108
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.530
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.547
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.476
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.658
# [NanoDet][11-26 00:13:09]INFO:Val_metrics: {'mAP': 0.45926675956604307, 'AP_50': 0.9189438710621598, 'AP_75': 0.41523631219243734, 'AP_small': 0.0, 'AP_m': 0.3906137944762488, 'AP_l': 0.5800054363600484}
# [NanoDet][11-26 00:13:10]INFO:Train|Epoch131/280|Iter130(0)| lr:6.86e-02| loss_qfl:0.1804| loss_bbox:0.4834| loss_dfl:0.2086|
# [NanoDet][11-26 00:13:22]INFO:Val|Epoch140/280|Iter139(0)| lr:7.24e-02| loss_qfl:0.4558| loss_bbox:0.5169| loss_dfl:0.2158|
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.20s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.472
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.917
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.391
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.401
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.587
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.100
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.521
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.543
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.480
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.646
# [NanoDet][11-26 00:13:23]INFO:Val_metrics: {'mAP': 0.47215837260031424, 'AP_50': 0.9171672486991699, 'AP_75': 0.3908953359638089, 'AP_small': 0.0, 'AP_m': 0.4006743764908966, 'AP_l': 0.5871357982543043}
# [NanoDet][11-26 00:13:24]INFO:Train|Epoch141/280|Iter140(0)| lr:7.28e-02| loss_qfl:0.1993| loss_bbox:0.4406| loss_dfl:0.1936|
# [NanoDet][11-26 00:13:36]INFO:Val|Epoch150/280|Iter149(0)| lr:7.66e-02| loss_qfl:0.2554| loss_bbox:0.4939| loss_dfl:0.2131|
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.17s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.458
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.935
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.401
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.362
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.584
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.104
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.536
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.464
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.673
# [NanoDet][11-26 00:13:37]INFO:Val_metrics: {'mAP': 0.457605560554407, 'AP_50': 0.9353936172347487, 'AP_75': 0.4013737351175162, 'AP_small': 0.0, 'AP_m': 0.3615944163304018, 'AP_l': 0.5840078555993343}
# [NanoDet][11-26 00:13:38]INFO:Train|Epoch151/280|Iter150(0)| lr:7.70e-02| loss_qfl:0.1459| loss_bbox:0.4162| loss_dfl:0.1913|
# [NanoDet][11-26 00:13:51]INFO:Val|Epoch160/280|Iter159(0)| lr:8.08e-02| loss_qfl:0.1410| loss_bbox:0.5228| loss_dfl:0.2143|
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.15s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.428
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.940
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.206
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.406
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.497
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.091
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.500
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.525
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.500
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.588
# [NanoDet][11-26 00:13:51]INFO:Val_metrics: {'mAP': 0.42802541306749814, 'AP_50': 0.9399036461892802, 'AP_75': 0.20580803881059997, 'AP_small': 0.0, 'AP_m': 0.4055802681161041, 'AP_l': 0.49690672616042486}
# [NanoDet][11-26 00:13:52]INFO:Train|Epoch161/280|Iter160(0)| lr:8.12e-02| loss_qfl:0.1416| loss_bbox:0.4460| loss_dfl:0.1979|
# [NanoDet][11-26 00:14:05]INFO:Val|Epoch170/280|Iter169(0)| lr:8.50e-02| loss_qfl:0.1456| loss_bbox:0.5662| loss_dfl:0.2223|
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.16s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.377
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.923
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.118
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.341
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.503
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.085
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.466
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.485
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.432
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.573
# [NanoDet][11-26 00:14:05]INFO:Val_metrics: {'mAP': 0.37651139698735003, 'AP_50': 0.9231505704258861, 'AP_75': 0.11804855672179655, 'AP_small': 0.0, 'AP_m': 0.3405396537482253, 'AP_l': 0.5031865458350234}
# [NanoDet][11-26 00:14:06]INFO:Train|Epoch171/280|Iter170(0)| lr:8.54e-02| loss_qfl:0.1421| loss_bbox:0.4701| loss_dfl:0.1977|
# [NanoDet][11-26 00:14:18]INFO:Val|Epoch180/280|Iter179(0)| lr:8.92e-02| loss_qfl:0.2045| loss_bbox:0.5104| loss_dfl:0.2133|
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.17s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.480
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.929
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.388
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.426
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.592
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.098
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.564
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.570
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.508
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.673
# [NanoDet][11-26 00:14:19]INFO:Val_metrics: {'mAP': 0.47963759889553564, 'AP_50': 0.9294156303608682, 'AP_75': 0.38835005499407027, 'AP_small': 0.0, 'AP_m': 0.42638741415304104, 'AP_l': 0.5922917701068203}
# [NanoDet][11-26 00:14:20]INFO:Train|Epoch181/280|Iter180(0)| lr:8.96e-02| loss_qfl:0.1469| loss_bbox:0.3795| loss_dfl:0.1820|
# [NanoDet][11-26 00:14:32]INFO:Val|Epoch190/280|Iter189(0)| lr:9.34e-02| loss_qfl:0.1785| loss_bbox:0.4873| loss_dfl:0.2040|
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.14s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.489
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.953
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.423
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.447
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.578
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.119
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.558
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.504
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.654
# [NanoDet][11-26 00:14:33]INFO:Val_metrics: {'mAP': 0.4890963977101632, 'AP_50': 0.9530109547922411, 'AP_75': 0.4231344273481881, 'AP_small': 0.0, 'AP_m': 0.44731268862297907, 'AP_l': 0.5775370871304637}
# [NanoDet][11-26 00:14:34]INFO:Train|Epoch191/280|Iter190(0)| lr:9.38e-02| loss_qfl:0.1222| loss_bbox:0.4089| loss_dfl:0.1811|
# [NanoDet][11-26 00:14:47]INFO:Val|Epoch200/280|Iter199(0)| lr:9.76e-02| loss_qfl:0.1532| loss_bbox:0.4987| loss_dfl:0.2106|
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.17s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.482
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.925
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.443
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.381
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.625
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.098
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.553
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.575
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.508
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.685
# [NanoDet][11-26 00:14:47]INFO:Val_metrics: {'mAP': 0.4822052537916065, 'AP_50': 0.9254454927367486, 'AP_75': 0.4434479756261935, 'AP_small': 0.0, 'AP_m': 0.38125548420862077, 'AP_l': 0.6249763473261681}
# [NanoDet][11-26 00:14:49]INFO:Train|Epoch201/280|Iter200(0)| lr:9.80e-02| loss_qfl:0.1301| loss_bbox:0.4054| loss_dfl:0.1833|
# [NanoDet][11-26 00:15:01]INFO:Val|Epoch210/280|Iter209(0)| lr:1.02e-01| loss_qfl:0.1485| loss_bbox:0.4831| loss_dfl:0.2080|
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.14s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.495
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.956
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.403
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.405
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.628
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.109
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.551
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.570
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.492
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.688
# [NanoDet][11-26 00:15:01]INFO:Val_metrics: {'mAP': 0.495142061444837, 'AP_50': 0.9555650855509413, 'AP_75': 0.40295081793953225, 'AP_small': 0.0, 'AP_m': 0.40536300817132603, 'AP_l': 0.6283535247687679}
# [NanoDet][11-26 00:15:03]INFO:Train|Epoch211/280|Iter210(0)| lr:1.02e-01| loss_qfl:0.1339| loss_bbox:0.4217| loss_dfl:0.1917|
# [NanoDet][11-26 00:15:15]INFO:Val|Epoch220/280|Iter219(0)| lr:1.06e-01| loss_qfl:0.1946| loss_bbox:0.4725| loss_dfl:0.2053|
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.11s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.508
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.939
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.487
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.436
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.623
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.104
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.575
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.577
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.516
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.681
# [NanoDet][11-26 00:15:15]INFO:Val_metrics: {'mAP': 0.5077334950198382, 'AP_50': 0.9388465284884653, 'AP_75': 0.48692043741124574, 'AP_small': 0.0, 'AP_m': 0.4360410979878723, 'AP_l': 0.6228072515201848}
# [NanoDet][11-26 00:15:17]INFO:Train|Epoch221/280|Iter220(0)| lr:1.06e-01| loss_qfl:0.1915| loss_bbox:0.4007| loss_dfl:0.1866|
# [NanoDet][11-26 00:15:29]INFO:Val|Epoch230/280|Iter229(0)| lr:1.10e-01| loss_qfl:0.2152| loss_bbox:0.4910| loss_dfl:0.2062|
# Loading and preparing results...
# DONE (t=0.17s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.16s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.476
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.956
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.378
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.404
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.592
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.113
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.562
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.504
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.662
# [NanoDet][11-26 00:15:29]INFO:Val_metrics: {'mAP': 0.4762565333080847, 'AP_50': 0.9563190200421661, 'AP_75': 0.37838462250115174, 'AP_small': 0.0, 'AP_m': 0.4042275558440071, 'AP_l': 0.5921077635489637}
# [NanoDet][11-26 00:15:31]INFO:Train|Epoch231/280|Iter230(0)| lr:1.11e-01| loss_qfl:0.1299| loss_bbox:0.4128| loss_dfl:0.1827|
# [NanoDet][11-26 00:15:43]INFO:Val|Epoch240/280|Iter239(0)| lr:1.14e-01| loss_qfl:0.1778| loss_bbox:0.4792| loss_dfl:0.2040|
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.15s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.513
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.932
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.475
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.434
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.628
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.113
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.577
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.583
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.532
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.677
# [NanoDet][11-26 00:15:43]INFO:Val_metrics: {'mAP': 0.5128219117166246, 'AP_50': 0.9324403028538147, 'AP_75': 0.4750338561060608, 'AP_small': 0.0, 'AP_m': 0.4343148088366046, 'AP_l': 0.6275061168581845}
# [NanoDet][11-26 00:15:45]INFO:Train|Epoch241/280|Iter240(0)| lr:1.15e-01| loss_qfl:0.1202| loss_bbox:0.3820| loss_dfl:0.1796|
# [NanoDet][11-26 00:15:57]INFO:Val|Epoch250/280|Iter249(0)| lr:1.19e-01| loss_qfl:0.1567| loss_bbox:0.5023| loss_dfl:0.2103|
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.15s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.462
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.935
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.417
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.415
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.575
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.096
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.536
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.496
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.642
# [NanoDet][11-26 00:15:57]INFO:Val_metrics: {'mAP': 0.4620915960651598, 'AP_50': 0.9345832002555096, 'AP_75': 0.4172664130213193, 'AP_small': 0.0, 'AP_m': 0.4146331461752564, 'AP_l': 0.5752015251214562}
# [NanoDet][11-26 00:15:59]INFO:Train|Epoch251/280|Iter250(0)| lr:1.19e-01| loss_qfl:0.1098| loss_bbox:0.3645| loss_dfl:0.1777|
# [NanoDet][11-26 00:16:11]INFO:Val|Epoch260/280|Iter259(0)| lr:1.23e-01| loss_qfl:0.1422| loss_bbox:0.5026| loss_dfl:0.2088|
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.14s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.466
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.928
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.390
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.417
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.559
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.104
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.519
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.543
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.492
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.635
# [NanoDet][11-26 00:16:11]INFO:Val_metrics: {'mAP': 0.466317139017776, 'AP_50': 0.9283349398980785, 'AP_75': 0.3900850569189372, 'AP_small': 0.0, 'AP_m': 0.4174217869911153, 'AP_l': 0.5587125661881243}
# [NanoDet][11-26 00:16:13]INFO:Train|Epoch261/280|Iter260(0)| lr:1.23e-01| loss_qfl:0.1385| loss_bbox:0.3587| loss_dfl:0.1737|
# [NanoDet][11-26 00:16:25]INFO:Val|Epoch270/280|Iter269(0)| lr:1.27e-01| loss_qfl:0.1521| loss_bbox:0.5502| loss_dfl:0.2161|
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.13s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.441
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.914
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.418
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.416
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.517
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.092
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.509
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.528
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.480
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.615
# [NanoDet][11-26 00:16:25]INFO:Val_metrics: {'mAP': 0.4412597797939983, 'AP_50': 0.9142017980339042, 'AP_75': 0.4184707787548942, 'AP_small': 0.0, 'AP_m': 0.4161164888160769, 'AP_l': 0.5170991076712204}
# [NanoDet][11-26 00:16:27]INFO:Train|Epoch271/280|Iter270(0)| lr:1.27e-01| loss_qfl:0.1424| loss_bbox:0.3748| loss_dfl:0.1730|
# [NanoDet][11-26 00:16:39]INFO:Val|Epoch280/280|Iter279(0)| lr:1.31e-01| loss_qfl:0.1566| loss_bbox:0.5091| loss_dfl:0.2092|
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.15s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.498
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.945
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.454
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.434
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.612
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.111
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.557
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.574
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.516
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.673
# [NanoDet][11-26 00:16:39]INFO:Val_metrics: {'mAP': 0.49817380738003036, 'AP_50': 0.9452360731779325, 'AP_75': 0.45414912362677323, 'AP_small': 0.0, 'AP_m': 0.43391335043187546, 'AP_l': 0.6124994998535905}

# %% [markdown]
# # ONNX変換(Convert to ONNX)

# %%
# !cp tools/export_onnx.py ./

# %%
# !python export_onnx.py \
    --cfg_path=nanodet-m.yml \
    --model_path=workspace/nanodet_m/model_best/model_best.ckpt
# Out:
# model size is  1.0x
# init weights...
# => loading pretrained model https://download.pytorch.org/models/shufflenetv2_x1-5666bf0f80.pth
# Finish initialize NanoDet Head.
# /content/nanodet/nanodet/model/backbone/shufflenetv2.py:18: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   channels_per_group = num_channels // groups
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3635: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode)
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3680: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# graph(%input.1 : Float(1, 3, 320, 320, strides=[307200, 102400, 320, 1], requires_grad=0, device=cpu),
#       %fpn.lateral_convs.0.conv.weight : Float(96, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=1, device=cpu),
#       %fpn.lateral_convs.0.conv.bias : Float(96, strides=[1], requires_grad=1, device=cpu),
#       %fpn.lateral_convs.1.conv.weight : Float(96, 232, 1, 1, strides=[232, 1, 1, 1], requires_grad=1, device=cpu),
#       %fpn.lateral_convs.1.conv.bias : Float(96, strides=[1], requires_grad=1, device=cpu),
#       %fpn.lateral_convs.2.conv.weight : Float(96, 464, 1, 1, strides=[464, 1, 1, 1], requires_grad=1, device=cpu),
#       %fpn.lateral_convs.2.conv.bias : Float(96, strides=[1], requires_grad=1, device=cpu),
#       %head.gfl_cls.0.weight : Float(33, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=1, device=cpu),
#       %head.gfl_cls.0.bias : Float(33, strides=[1], requires_grad=1, device=cpu),
#       %head.gfl_cls.1.weight : Float(33, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=1, device=cpu),
#       %head.gfl_cls.1.bias : Float(33, strides=[1], requires_grad=1, device=cpu),
#       %head.gfl_cls.2.weight : Float(33, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=1, device=cpu),
#       %head.gfl_cls.2.bias : Float(33, strides=[1], requires_grad=1, device=cpu),
#       %941 : Float(24, 3, 3, 3, strides=[27, 9, 3, 1], requires_grad=0, device=cpu),
#       %942 : Float(24, strides=[1], requires_grad=0, device=cpu),
#       %944 : Float(24, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %945 : Float(24, strides=[1], requires_grad=0, device=cpu),
#       %947 : Float(58, 24, 1, 1, strides=[24, 1, 1, 1], requires_grad=0, device=cpu),
#       %948 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %950 : Float(58, 24, 1, 1, strides=[24, 1, 1, 1], requires_grad=0, device=cpu),
#       %951 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %953 : Float(58, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %954 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %956 : Float(58, 58, 1, 1, strides=[58, 1, 1, 1], requires_grad=0, device=cpu),
#       %957 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %959 : Float(58, 58, 1, 1, strides=[58, 1, 1, 1], requires_grad=0, device=cpu),
#       %960 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %962 : Float(58, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %963 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %965 : Float(58, 58, 1, 1, strides=[58, 1, 1, 1], requires_grad=0, device=cpu),
#       %966 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %968 : Float(58, 58, 1, 1, strides=[58, 1, 1, 1], requires_grad=0, device=cpu),
#       %969 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %971 : Float(58, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %972 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %974 : Float(58, 58, 1, 1, strides=[58, 1, 1, 1], requires_grad=0, device=cpu),
#       %975 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %977 : Float(58, 58, 1, 1, strides=[58, 1, 1, 1], requires_grad=0, device=cpu),
#       %978 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %980 : Float(58, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %981 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %983 : Float(58, 58, 1, 1, strides=[58, 1, 1, 1], requires_grad=0, device=cpu),
#       %984 : Float(58, strides=[1], requires_grad=0, device=cpu),
#       %986 : Float(116, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %987 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %989 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %990 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %992 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %993 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %995 : Float(116, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %996 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %998 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %999 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1001 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1002 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1004 : Float(116, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1005 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1007 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1008 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1010 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1011 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1013 : Float(116, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1014 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1016 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1017 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1019 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1020 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1022 : Float(116, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1023 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1025 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1026 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1028 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1029 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1031 : Float(116, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1032 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1034 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1035 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1037 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1038 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1040 : Float(116, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1041 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1043 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1044 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1046 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1047 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1049 : Float(116, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1050 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1052 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1053 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1055 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1056 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1058 : Float(116, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1059 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1061 : Float(116, 116, 1, 1, strides=[116, 1, 1, 1], requires_grad=0, device=cpu),
#       %1062 : Float(116, strides=[1], requires_grad=0, device=cpu),
#       %1064 : Float(232, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1065 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1067 : Float(232, 232, 1, 1, strides=[232, 1, 1, 1], requires_grad=0, device=cpu),
#       %1068 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1070 : Float(232, 232, 1, 1, strides=[232, 1, 1, 1], requires_grad=0, device=cpu),
#       %1071 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1073 : Float(232, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1074 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1076 : Float(232, 232, 1, 1, strides=[232, 1, 1, 1], requires_grad=0, device=cpu),
#       %1077 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1079 : Float(232, 232, 1, 1, strides=[232, 1, 1, 1], requires_grad=0, device=cpu),
#       %1080 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1082 : Float(232, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1083 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1085 : Float(232, 232, 1, 1, strides=[232, 1, 1, 1], requires_grad=0, device=cpu),
#       %1086 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1088 : Float(232, 232, 1, 1, strides=[232, 1, 1, 1], requires_grad=0, device=cpu),
#       %1089 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1091 : Float(232, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1092 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1094 : Float(232, 232, 1, 1, strides=[232, 1, 1, 1], requires_grad=0, device=cpu),
#       %1095 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1097 : Float(232, 232, 1, 1, strides=[232, 1, 1, 1], requires_grad=0, device=cpu),
#       %1098 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1100 : Float(232, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1101 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1103 : Float(232, 232, 1, 1, strides=[232, 1, 1, 1], requires_grad=0, device=cpu),
#       %1104 : Float(232, strides=[1], requires_grad=0, device=cpu),
#       %1106 : Float(96, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1107 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1109 : Float(96, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %1110 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1112 : Float(96, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1113 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1115 : Float(96, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %1116 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1118 : Float(96, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1119 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1121 : Float(96, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %1122 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1124 : Float(96, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1125 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1127 : Float(96, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %1128 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1130 : Float(96, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1131 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1133 : Float(96, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %1134 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1136 : Float(96, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=0, device=cpu),
#       %1137 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1139 : Float(96, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cpu),
#       %1140 : Float(96, strides=[1], requires_grad=0, device=cpu),
#       %1141 : Float(4, strides=[1], requires_grad=0, device=cpu),
#       %1142 : Float(4, strides=[1], requires_grad=0, device=cpu),
#       %1143 : Float(4, strides=[1], requires_grad=0, device=cpu),
#       %1144 : Float(4, strides=[1], requires_grad=0, device=cpu)):
#   %940 : Float(1, 24, 160, 160, strides=[614400, 25600, 160, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%input.1, %941, %942)
#   %424 : Float(1, 24, 160, 160, strides=[614400, 25600, 160, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%940) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %425 : Float(1, 24, 80, 80, strides=[153600, 6400, 80, 1], requires_grad=1, device=cpu) = onnx::MaxPool[ceil_mode=0, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%424) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:719:0
#   %943 : Float(1, 24, 40, 40, strides=[38400, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=24, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%425, %944, %945)
#   %946 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%943, %947, %948)
#   %430 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%946) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %949 : Float(1, 58, 80, 80, strides=[371200, 6400, 80, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%425, %950, %951)
#   %433 : Float(1, 58, 80, 80, strides=[371200, 6400, 80, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%949) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %952 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=58, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%433, %953, %954)
#   %955 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%952, %956, %957)
#   %438 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%955) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %439 : Float(1, 116, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%430, %438) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:97:0
#   %440 : Long(5, strides=[1], device=cpu) = onnx::Constant[value=  1   2  58  40  40 [ CPULongType{5} ]]()
#   %441 : Float(1, 2, 58, 40, 40, strides=[185600, 92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Reshape(%439, %440) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:21:0
#   %442 : Float(1, 58, 2, 40, 40, strides=[185600, 3200, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3, 4]](%441) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:23:0
#   %443 : Long(4, strides=[1], device=cpu) = onnx::Constant[value=  1  -1  40  40 [ CPULongType{4} ]]()
#   %444 : Float(1, 116, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Reshape(%442, %443) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:26:0
#   %445 : Long(4, strides=[1], device=cpu) = onnx::Shape(%444)
#   %446 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %447 : Long(1, strides=[1], device=cpu) = onnx::Gather[axis=0](%445, %446)
#   %448 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %449 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %450 : Long(1, strides=[1], device=cpu) = onnx::Add(%447, %449)
#   %451 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %452 : Long(1, strides=[1], device=cpu) = onnx::Div(%450, %451)
#   %453 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %454 : Long(1, strides=[1], device=cpu) = onnx::Mul(%452, %453)
#   %455 : Float(1, 58, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Slice(%444, %448, %454, %446)
#   %456 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %457 : Long(1, strides=[1], device=cpu) = onnx::Mul(%452, %456)
#   %458 : Float(1, 58, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Slice(%444, %454, %457, %446)
#   %958 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%458, %959, %960)
#   %461 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%958) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %961 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=58, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%461, %962, %963)
#   %964 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%961, %965, %966)
#   %466 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%964) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %467 : Float(1, 116, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%455, %466) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:95:0
#   %468 : Long(5, strides=[1], device=cpu) = onnx::Constant[value=  1   2  58  40  40 [ CPULongType{5} ]]()
#   %469 : Float(1, 2, 58, 40, 40, strides=[185600, 92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Reshape(%467, %468) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:21:0
#   %470 : Float(1, 58, 2, 40, 40, strides=[185600, 3200, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3, 4]](%469) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:23:0
#   %471 : Long(4, strides=[1], device=cpu) = onnx::Constant[value=  1  -1  40  40 [ CPULongType{4} ]]()
#   %472 : Float(1, 116, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Reshape(%470, %471) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:26:0
#   %473 : Long(4, strides=[1], device=cpu) = onnx::Shape(%472)
#   %474 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %475 : Long(1, strides=[1], device=cpu) = onnx::Gather[axis=0](%473, %474)
#   %476 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %477 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %478 : Long(1, strides=[1], device=cpu) = onnx::Add(%475, %477)
#   %479 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %480 : Long(1, strides=[1], device=cpu) = onnx::Div(%478, %479)
#   %481 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %482 : Long(1, strides=[1], device=cpu) = onnx::Mul(%480, %481)
#   %483 : Float(1, 58, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Slice(%472, %476, %482, %474)
#   %484 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %485 : Long(1, strides=[1], device=cpu) = onnx::Mul(%480, %484)
#   %486 : Float(1, 58, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Slice(%472, %482, %485, %474)
#   %967 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%486, %968, %969)
#   %489 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%967) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %970 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=58, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%489, %971, %972)
#   %973 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%970, %974, %975)
#   %494 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%973) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %495 : Float(1, 116, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%483, %494) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:95:0
#   %496 : Long(5, strides=[1], device=cpu) = onnx::Constant[value=  1   2  58  40  40 [ CPULongType{5} ]]()
#   %497 : Float(1, 2, 58, 40, 40, strides=[185600, 92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Reshape(%495, %496) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:21:0
#   %498 : Float(1, 58, 2, 40, 40, strides=[185600, 3200, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3, 4]](%497) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:23:0
#   %499 : Long(4, strides=[1], device=cpu) = onnx::Constant[value=  1  -1  40  40 [ CPULongType{4} ]]()
#   %500 : Float(1, 116, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Reshape(%498, %499) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:26:0
#   %501 : Long(4, strides=[1], device=cpu) = onnx::Shape(%500)
#   %502 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %503 : Long(1, strides=[1], device=cpu) = onnx::Gather[axis=0](%501, %502)
#   %504 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %505 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %506 : Long(1, strides=[1], device=cpu) = onnx::Add(%503, %505)
#   %507 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %508 : Long(1, strides=[1], device=cpu) = onnx::Div(%506, %507)
#   %509 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %510 : Long(1, strides=[1], device=cpu) = onnx::Mul(%508, %509)
#   %511 : Float(1, 58, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Slice(%500, %504, %510, %502)
#   %512 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %513 : Long(1, strides=[1], device=cpu) = onnx::Mul(%508, %512)
#   %514 : Float(1, 58, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Slice(%500, %510, %513, %502)
#   %976 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%514, %977, %978)
#   %517 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%976) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %979 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=58, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%517, %980, %981)
#   %982 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%979, %983, %984)
#   %522 : Float(1, 58, 40, 40, strides=[92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%982) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %523 : Float(1, 116, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%511, %522) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:95:0
#   %524 : Long(5, strides=[1], device=cpu) = onnx::Constant[value=  1   2  58  40  40 [ CPULongType{5} ]]()
#   %525 : Float(1, 2, 58, 40, 40, strides=[185600, 92800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Reshape(%523, %524) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:21:0
#   %526 : Float(1, 58, 2, 40, 40, strides=[185600, 3200, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3, 4]](%525) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:23:0
#   %527 : Long(4, strides=[1], device=cpu) = onnx::Constant[value=  1  -1  40  40 [ CPULongType{4} ]]()
#   %528 : Float(1, 116, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Reshape(%526, %527) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:26:0
#   %985 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=116, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%528, %986, %987)
#   %988 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%985, %989, %990)
#   %533 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%988) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %991 : Float(1, 116, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%528, %992, %993)
#   %536 : Float(1, 116, 40, 40, strides=[185600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%991) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %994 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=116, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%536, %995, %996)
#   %997 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%994, %998, %999)
#   %541 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%997) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %542 : Float(1, 232, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%533, %541) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:97:0
#   %543 : Long(5, strides=[1], device=cpu) = onnx::Constant[value=   1    2  116   20   20 [ CPULongType{5} ]]()
#   %544 : Float(1, 2, 116, 20, 20, strides=[92800, 46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Reshape(%542, %543) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:21:0
#   %545 : Float(1, 116, 2, 20, 20, strides=[92800, 800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3, 4]](%544) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:23:0
#   %546 : Long(4, strides=[1], device=cpu) = onnx::Constant[value=  1  -1  20  20 [ CPULongType{4} ]]()
#   %547 : Float(1, 232, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Reshape(%545, %546) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:26:0
#   %548 : Long(4, strides=[1], device=cpu) = onnx::Shape(%547)
#   %549 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %550 : Long(1, strides=[1], device=cpu) = onnx::Gather[axis=0](%548, %549)
#   %551 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %552 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %553 : Long(1, strides=[1], device=cpu) = onnx::Add(%550, %552)
#   %554 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %555 : Long(1, strides=[1], device=cpu) = onnx::Div(%553, %554)
#   %556 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %557 : Long(1, strides=[1], device=cpu) = onnx::Mul(%555, %556)
#   %558 : Float(1, 116, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Slice(%547, %551, %557, %549)
#   %559 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %560 : Long(1, strides=[1], device=cpu) = onnx::Mul(%555, %559)
#   %561 : Float(1, 116, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Slice(%547, %557, %560, %549)
#   %1000 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%561, %1001, %1002)
#   %564 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1000) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %1003 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=116, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%564, %1004, %1005)
#   %1006 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1003, %1007, %1008)
#   %569 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1006) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %570 : Float(1, 232, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%558, %569) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:95:0
#   %571 : Long(5, strides=[1], device=cpu) = onnx::Constant[value=   1    2  116   20   20 [ CPULongType{5} ]]()
#   %572 : Float(1, 2, 116, 20, 20, strides=[92800, 46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Reshape(%570, %571) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:21:0
#   %573 : Float(1, 116, 2, 20, 20, strides=[92800, 800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3, 4]](%572) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:23:0
#   %574 : Long(4, strides=[1], device=cpu) = onnx::Constant[value=  1  -1  20  20 [ CPULongType{4} ]]()
#   %575 : Float(1, 232, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Reshape(%573, %574) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:26:0
#   %576 : Long(4, strides=[1], device=cpu) = onnx::Shape(%575)
#   %577 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %578 : Long(1, strides=[1], device=cpu) = onnx::Gather[axis=0](%576, %577)
#   %579 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %580 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %581 : Long(1, strides=[1], device=cpu) = onnx::Add(%578, %580)
#   %582 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %583 : Long(1, strides=[1], device=cpu) = onnx::Div(%581, %582)
#   %584 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %585 : Long(1, strides=[1], device=cpu) = onnx::Mul(%583, %584)
#   %586 : Float(1, 116, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Slice(%575, %579, %585, %577)
#   %587 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %588 : Long(1, strides=[1], device=cpu) = onnx::Mul(%583, %587)
#   %589 : Float(1, 116, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Slice(%575, %585, %588, %577)
#   %1009 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%589, %1010, %1011)
#   %592 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1009) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %1012 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=116, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%592, %1013, %1014)
#   %1015 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1012, %1016, %1017)
#   %597 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1015) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %598 : Float(1, 232, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%586, %597) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:95:0
#   %599 : Long(5, strides=[1], device=cpu) = onnx::Constant[value=   1    2  116   20   20 [ CPULongType{5} ]]()
#   %600 : Float(1, 2, 116, 20, 20, strides=[92800, 46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Reshape(%598, %599) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:21:0
#   %601 : Float(1, 116, 2, 20, 20, strides=[92800, 800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3, 4]](%600) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:23:0
#   %602 : Long(4, strides=[1], device=cpu) = onnx::Constant[value=  1  -1  20  20 [ CPULongType{4} ]]()
#   %603 : Float(1, 232, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Reshape(%601, %602) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:26:0
#   %604 : Long(4, strides=[1], device=cpu) = onnx::Shape(%603)
#   %605 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %606 : Long(1, strides=[1], device=cpu) = onnx::Gather[axis=0](%604, %605)
#   %607 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %608 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %609 : Long(1, strides=[1], device=cpu) = onnx::Add(%606, %608)
#   %610 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %611 : Long(1, strides=[1], device=cpu) = onnx::Div(%609, %610)
#   %612 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %613 : Long(1, strides=[1], device=cpu) = onnx::Mul(%611, %612)
#   %614 : Float(1, 116, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Slice(%603, %607, %613, %605)
#   %615 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %616 : Long(1, strides=[1], device=cpu) = onnx::Mul(%611, %615)
#   %617 : Float(1, 116, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Slice(%603, %613, %616, %605)
#   %1018 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%617, %1019, %1020)
#   %620 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1018) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %1021 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=116, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%620, %1022, %1023)
#   %1024 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1021, %1025, %1026)
#   %625 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1024) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %626 : Float(1, 232, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%614, %625) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:95:0
#   %627 : Long(5, strides=[1], device=cpu) = onnx::Constant[value=   1    2  116   20   20 [ CPULongType{5} ]]()
#   %628 : Float(1, 2, 116, 20, 20, strides=[92800, 46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Reshape(%626, %627) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:21:0
#   %629 : Float(1, 116, 2, 20, 20, strides=[92800, 800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3, 4]](%628) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:23:0
#   %630 : Long(4, strides=[1], device=cpu) = onnx::Constant[value=  1  -1  20  20 [ CPULongType{4} ]]()
#   %631 : Float(1, 232, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Reshape(%629, %630) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:26:0
#   %632 : Long(4, strides=[1], device=cpu) = onnx::Shape(%631)
#   %633 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %634 : Long(1, strides=[1], device=cpu) = onnx::Gather[axis=0](%632, %633)
#   %635 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %636 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %637 : Long(1, strides=[1], device=cpu) = onnx::Add(%634, %636)
#   %638 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %639 : Long(1, strides=[1], device=cpu) = onnx::Div(%637, %638)
#   %640 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %641 : Long(1, strides=[1], device=cpu) = onnx::Mul(%639, %640)
#   %642 : Float(1, 116, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Slice(%631, %635, %641, %633)
#   %643 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %644 : Long(1, strides=[1], device=cpu) = onnx::Mul(%639, %643)
#   %645 : Float(1, 116, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Slice(%631, %641, %644, %633)
#   %1027 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%645, %1028, %1029)
#   %648 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1027) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %1030 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=116, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%648, %1031, %1032)
#   %1033 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1030, %1034, %1035)
#   %653 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1033) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %654 : Float(1, 232, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%642, %653) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:95:0
#   %655 : Long(5, strides=[1], device=cpu) = onnx::Constant[value=   1    2  116   20   20 [ CPULongType{5} ]]()
#   %656 : Float(1, 2, 116, 20, 20, strides=[92800, 46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Reshape(%654, %655) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:21:0
#   %657 : Float(1, 116, 2, 20, 20, strides=[92800, 800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3, 4]](%656) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:23:0
#   %658 : Long(4, strides=[1], device=cpu) = onnx::Constant[value=  1  -1  20  20 [ CPULongType{4} ]]()
#   %659 : Float(1, 232, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Reshape(%657, %658) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:26:0
#   %660 : Long(4, strides=[1], device=cpu) = onnx::Shape(%659)
#   %661 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %662 : Long(1, strides=[1], device=cpu) = onnx::Gather[axis=0](%660, %661)
#   %663 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %664 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %665 : Long(1, strides=[1], device=cpu) = onnx::Add(%662, %664)
#   %666 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %667 : Long(1, strides=[1], device=cpu) = onnx::Div(%665, %666)
#   %668 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %669 : Long(1, strides=[1], device=cpu) = onnx::Mul(%667, %668)
#   %670 : Float(1, 116, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Slice(%659, %663, %669, %661)
#   %671 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %672 : Long(1, strides=[1], device=cpu) = onnx::Mul(%667, %671)
#   %673 : Float(1, 116, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Slice(%659, %669, %672, %661)
#   %1036 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%673, %1037, %1038)
#   %676 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1036) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %1039 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=116, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%676, %1040, %1041)
#   %1042 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1039, %1043, %1044)
#   %681 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1042) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %682 : Float(1, 232, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%670, %681) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:95:0
#   %683 : Long(5, strides=[1], device=cpu) = onnx::Constant[value=   1    2  116   20   20 [ CPULongType{5} ]]()
#   %684 : Float(1, 2, 116, 20, 20, strides=[92800, 46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Reshape(%682, %683) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:21:0
#   %685 : Float(1, 116, 2, 20, 20, strides=[92800, 800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3, 4]](%684) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:23:0
#   %686 : Long(4, strides=[1], device=cpu) = onnx::Constant[value=  1  -1  20  20 [ CPULongType{4} ]]()
#   %687 : Float(1, 232, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Reshape(%685, %686) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:26:0
#   %688 : Long(4, strides=[1], device=cpu) = onnx::Shape(%687)
#   %689 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %690 : Long(1, strides=[1], device=cpu) = onnx::Gather[axis=0](%688, %689)
#   %691 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %692 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %693 : Long(1, strides=[1], device=cpu) = onnx::Add(%690, %692)
#   %694 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %695 : Long(1, strides=[1], device=cpu) = onnx::Div(%693, %694)
#   %696 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %697 : Long(1, strides=[1], device=cpu) = onnx::Mul(%695, %696)
#   %698 : Float(1, 116, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Slice(%687, %691, %697, %689)
#   %699 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %700 : Long(1, strides=[1], device=cpu) = onnx::Mul(%695, %699)
#   %701 : Float(1, 116, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Slice(%687, %697, %700, %689)
#   %1045 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%701, %1046, %1047)
#   %704 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1045) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %1048 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=116, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%704, %1049, %1050)
#   %1051 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1048, %1052, %1053)
#   %709 : Float(1, 116, 20, 20, strides=[46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1051) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %710 : Float(1, 232, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%698, %709) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:95:0
#   %711 : Long(5, strides=[1], device=cpu) = onnx::Constant[value=   1    2  116   20   20 [ CPULongType{5} ]]()
#   %712 : Float(1, 2, 116, 20, 20, strides=[92800, 46400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Reshape(%710, %711) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:21:0
#   %713 : Float(1, 116, 2, 20, 20, strides=[92800, 800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3, 4]](%712) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:23:0
#   %714 : Long(4, strides=[1], device=cpu) = onnx::Constant[value=  1  -1  20  20 [ CPULongType{4} ]]()
#   %715 : Float(1, 232, 20, 20, strides=[92800, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Reshape(%713, %714) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:26:0
# ...
#   %824 : Long(1, strides=[1], device=cpu) = onnx::Add(%821, %823)
#   %825 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %826 : Long(1, strides=[1], device=cpu) = onnx::Div(%824, %825)
#   %827 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %828 : Long(1, strides=[1], device=cpu) = onnx::Mul(%826, %827)
#   %829 : Float(1, 232, 10, 10, strides=[46400, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Slice(%818, %822, %828, %820)
#   %830 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %831 : Long(1, strides=[1], device=cpu) = onnx::Mul(%826, %830)
#   %832 : Float(1, 232, 10, 10, strides=[46400, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Slice(%818, %828, %831, %820)
#   %1096 : Float(1, 232, 10, 10, strides=[23200, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%832, %1097, %1098)
#   %835 : Float(1, 232, 10, 10, strides=[23200, 100, 10, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1096) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %1099 : Float(1, 232, 10, 10, strides=[23200, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=232, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%835, %1100, %1101)
#   %1102 : Float(1, 232, 10, 10, strides=[23200, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1099, %1103, %1104)
#   %840 : Float(1, 232, 10, 10, strides=[23200, 100, 10, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1102) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %841 : Float(1, 464, 10, 10, strides=[46400, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%829, %840) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:95:0
#   %842 : Long(5, strides=[1], device=cpu) = onnx::Constant[value=   1    2  232   10   10 [ CPULongType{5} ]]()
#   %843 : Float(1, 2, 232, 10, 10, strides=[46400, 23200, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Reshape(%841, %842) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:21:0
#   %844 : Float(1, 232, 2, 10, 10, strides=[46400, 200, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1, 3, 4]](%843) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:23:0
#   %845 : Long(4, strides=[1], device=cpu) = onnx::Constant[value=  1  -1  10  10 [ CPULongType{4} ]]()
#   %846 : Float(1, 464, 10, 10, strides=[46400, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Reshape(%844, %845) # /content/nanodet/nanodet/model/backbone/shufflenetv2.py:26:0
#   %847 : Float(1, 96, 40, 40, strides=[153600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%528, %fpn.lateral_convs.0.conv.weight, %fpn.lateral_convs.0.conv.bias) # /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py:443:0
#   %848 : Float(1, 96, 20, 20, strides=[38400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%743, %fpn.lateral_convs.1.conv.weight, %fpn.lateral_convs.1.conv.bias) # /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py:443:0
#   %849 : Float(1, 96, 10, 10, strides=[9600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%846, %fpn.lateral_convs.2.conv.weight, %fpn.lateral_convs.2.conv.bias) # /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py:443:0
#   %853 : Float(0, strides=[1], device=cpu) = onnx::Constant[value=[ CPUFloatType{0} ]]()
#   %854 : Float(1, 96, 20, 20, strides=[38400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Resize[coordinate_transformation_mode="pytorch_half_pixel", cubic_coeff_a=-0.75, mode="linear", nearest_mode="floor"](%849, %853, %1141)
#   %855 : Float(1, 96, 20, 20, strides=[38400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Add(%848, %854) # /content/nanodet/nanodet/model/fpn/pan.py:78:0
#   %859 : Float(0, strides=[1], device=cpu) = onnx::Constant[value=[ CPUFloatType{0} ]]()
#   %860 : Float(1, 96, 40, 40, strides=[153600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Resize[coordinate_transformation_mode="pytorch_half_pixel", cubic_coeff_a=-0.75, mode="linear", nearest_mode="floor"](%855, %859, %1142)
#   %861 : Float(1, 96, 40, 40, strides=[153600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Add(%847, %860) # /content/nanodet/nanodet/model/fpn/pan.py:78:0
#   %865 : Float(0, strides=[1], device=cpu) = onnx::Constant[value=[ CPUFloatType{0} ]]()
#   %866 : Float(1, 96, 20, 20, strides=[38400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Resize[coordinate_transformation_mode="pytorch_half_pixel", cubic_coeff_a=-0.75, mode="linear", nearest_mode="floor"](%861, %865, %1143)
#   %867 : Float(1, 96, 20, 20, strides=[38400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Add(%855, %866) # /content/nanodet/nanodet/model/fpn/pan.py:88:0
#   %871 : Float(0, strides=[1], device=cpu) = onnx::Constant[value=[ CPUFloatType{0} ]]()
#   %872 : Float(1, 96, 10, 10, strides=[9600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Resize[coordinate_transformation_mode="pytorch_half_pixel", cubic_coeff_a=-0.75, mode="linear", nearest_mode="floor"](%867, %871, %1144)
#   %873 : Float(1, 96, 10, 10, strides=[9600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Add(%849, %872) # /content/nanodet/nanodet/model/fpn/pan.py:88:0
#   %1105 : Float(1, 96, 40, 40, strides=[153600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=96, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%861, %1106, %1107)
#   %876 : Float(1, 96, 40, 40, strides=[153600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1105) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %1108 : Float(1, 96, 40, 40, strides=[153600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%876, %1109, %1110)
#   %879 : Float(1, 96, 40, 40, strides=[153600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1108) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %1111 : Float(1, 96, 40, 40, strides=[153600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=96, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%879, %1112, %1113)
#   %882 : Float(1, 96, 40, 40, strides=[153600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1111) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %1114 : Float(1, 96, 40, 40, strides=[153600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%882, %1115, %1116)
#   %885 : Float(1, 96, 40, 40, strides=[153600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1114) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %886 : Float(1, 33, 40, 40, strides=[52800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%885, %head.gfl_cls.0.weight, %head.gfl_cls.0.bias) # /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py:443:0
#   %887 : Float(1, 1, 40, 40, strides=[52800, 1600, 40, 1], requires_grad=1, device=cpu), %888 : Float(1, 32, 40, 40, strides=[52800, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Split[axis=1, split=[1, 32]](%886) # /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:518:0
#   %889 : Float(1, 1, 40, 40, strides=[1600, 1600, 40, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%887) # /content/nanodet/nanodet/model/head/nanodet_head.py:168:0
#   %890 : Long(3, strides=[1], device=cpu) = onnx::Constant[value= 1  1 -1 [ CPULongType{3} ]]()
#   %891 : Float(1, 1, 1600, strides=[1600, 1600, 1], requires_grad=1, device=cpu) = onnx::Reshape(%889, %890) # /content/nanodet/nanodet/model/head/nanodet_head.py:169:0
#   %cls_pred_stride_8 : Float(1, 1600, 1, strides=[1600, 1, 1600], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1]](%891) # /content/nanodet/nanodet/model/head/nanodet_head.py:170:0
#   %893 : Long(3, strides=[1], device=cpu) = onnx::Constant[value=  1  32  -1 [ CPULongType{3} ]]()
#   %894 : Float(1, 32, 1600, strides=[51200, 1600, 1], requires_grad=1, device=cpu) = onnx::Reshape(%888, %893) # /content/nanodet/nanodet/model/head/nanodet_head.py:172:0
#   %dis_pred_stride_8 : Float(1, 1600, 32, strides=[51200, 1, 1600], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1]](%894) # /content/nanodet/nanodet/model/head/nanodet_head.py:173:0
#   %1117 : Float(1, 96, 20, 20, strides=[38400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=96, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%867, %1118, %1119)
#   %898 : Float(1, 96, 20, 20, strides=[38400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1117) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %1120 : Float(1, 96, 20, 20, strides=[38400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%898, %1121, %1122)
#   %901 : Float(1, 96, 20, 20, strides=[38400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1120) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %1123 : Float(1, 96, 20, 20, strides=[38400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=96, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%901, %1124, %1125)
#   %904 : Float(1, 96, 20, 20, strides=[38400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1123) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %1126 : Float(1, 96, 20, 20, strides=[38400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%904, %1127, %1128)
#   %907 : Float(1, 96, 20, 20, strides=[38400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1126) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %908 : Float(1, 33, 20, 20, strides=[13200, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%907, %head.gfl_cls.1.weight, %head.gfl_cls.1.bias) # /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py:443:0
#   %909 : Float(1, 1, 20, 20, strides=[13200, 400, 20, 1], requires_grad=1, device=cpu), %910 : Float(1, 32, 20, 20, strides=[13200, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Split[axis=1, split=[1, 32]](%908) # /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:518:0
#   %911 : Float(1, 1, 20, 20, strides=[400, 400, 20, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%909) # /content/nanodet/nanodet/model/head/nanodet_head.py:168:0
#   %912 : Long(3, strides=[1], device=cpu) = onnx::Constant[value= 1  1 -1 [ CPULongType{3} ]]()
#   %913 : Float(1, 1, 400, strides=[400, 400, 1], requires_grad=1, device=cpu) = onnx::Reshape(%911, %912) # /content/nanodet/nanodet/model/head/nanodet_head.py:169:0
#   %cls_pred_stride_16 : Float(1, 400, 1, strides=[400, 1, 400], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1]](%913) # /content/nanodet/nanodet/model/head/nanodet_head.py:170:0
#   %915 : Long(3, strides=[1], device=cpu) = onnx::Constant[value=  1  32  -1 [ CPULongType{3} ]]()
#   %916 : Float(1, 32, 400, strides=[12800, 400, 1], requires_grad=1, device=cpu) = onnx::Reshape(%910, %915) # /content/nanodet/nanodet/model/head/nanodet_head.py:172:0
#   %dis_pred_stride_16 : Float(1, 400, 32, strides=[12800, 1, 400], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1]](%916) # /content/nanodet/nanodet/model/head/nanodet_head.py:173:0
#   %1129 : Float(1, 96, 10, 10, strides=[9600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=96, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%873, %1130, %1131)
#   %920 : Float(1, 96, 10, 10, strides=[9600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1129) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %1132 : Float(1, 96, 10, 10, strides=[9600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%920, %1133, %1134)
#   %923 : Float(1, 96, 10, 10, strides=[9600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1132) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %1135 : Float(1, 96, 10, 10, strides=[9600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=96, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%923, %1136, %1137)
#   %926 : Float(1, 96, 10, 10, strides=[9600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1135) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %1138 : Float(1, 96, 10, 10, strides=[9600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%926, %1139, %1140)
#   %929 : Float(1, 96, 10, 10, strides=[9600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::LeakyRelu[alpha=0.10000000000000001](%1138) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1473:0
#   %930 : Float(1, 33, 10, 10, strides=[3300, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%929, %head.gfl_cls.2.weight, %head.gfl_cls.2.bias) # /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py:443:0
#   %931 : Float(1, 1, 10, 10, strides=[3300, 100, 10, 1], requires_grad=1, device=cpu), %932 : Float(1, 32, 10, 10, strides=[3300, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Split[axis=1, split=[1, 32]](%930) # /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:518:0
#   %933 : Float(1, 1, 10, 10, strides=[100, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%931) # /content/nanodet/nanodet/model/head/nanodet_head.py:168:0
#   %934 : Long(3, strides=[1], device=cpu) = onnx::Constant[value= 1  1 -1 [ CPULongType{3} ]]()
#   %935 : Float(1, 1, 100, strides=[100, 100, 1], requires_grad=1, device=cpu) = onnx::Reshape(%933, %934) # /content/nanodet/nanodet/model/head/nanodet_head.py:169:0
#   %cls_pred_stride_32 : Float(1, 100, 1, strides=[100, 1, 100], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1]](%935) # /content/nanodet/nanodet/model/head/nanodet_head.py:170:0
#   %937 : Long(3, strides=[1], device=cpu) = onnx::Constant[value=  1  32  -1 [ CPULongType{3} ]]()
#   %938 : Float(1, 32, 100, strides=[3200, 100, 1], requires_grad=1, device=cpu) = onnx::Reshape(%932, %937) # /content/nanodet/nanodet/model/head/nanodet_head.py:172:0
#   %dis_pred_stride_32 : Float(1, 100, 32, strides=[3200, 1, 100], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1]](%938) # /content/nanodet/nanodet/model/head/nanodet_head.py:173:0
#   return (%cls_pred_stride_8, %cls_pred_stride_16, %cls_pred_stride_32, %dis_pred_stride_8, %dis_pred_stride_16, %dis_pred_stride_32)
#
# [root][11-26 00:16:49]INFO:finished exporting onnx
# Model saved to: nanodet.onnx

# %%
# !pip install onnx-simplifier
# Out:
# Collecting onnx-simplifier
#   Downloading onnx-simplifier-0.3.6.tar.gz (13 kB)
# Collecting onnx
#   Downloading onnx-1.10.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (12.7 MB)
#      |████████████████████████████████| 12.7 MB 4.2 MB/s
# Collecting onnxoptimizer>=0.2.5
#   Downloading onnxoptimizer-0.2.6-cp37-cp37m-manylinux2014_x86_64.whl (466 kB)
#      |████████████████████████████████| 466 kB 36.4 MB/s
# Collecting onnxruntime>=1.6.0
#   Downloading onnxruntime-1.9.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      |████████████████████████████████| 4.8 MB 17.5 MB/s
# Requirement already satisfied: protobuf>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from onnx-simplifier) (3.17.3)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.7/dist-packages (from onnxruntime>=1.6.0->onnx-simplifier) (2.0)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.7/dist-packages (from onnxruntime>=1.6.0->onnx-simplifier) (1.19.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.7.0->onnx-simplifier) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.7/dist-packages (from onnx->onnx-simplifier) (3.10.0.2)
# Building wheels for collected packages: onnx-simplifier
#   Building wheel for onnx-simplifier (setup.py) ... done
#   Created wheel for onnx-simplifier: filename=onnx_simplifier-0.3.6-py3-none-any.whl size=12873 sha256=07530e3c350408aab84b56b2012a696e293cde8ddd6993614d3fc596cd04b307
#   Stored in directory: /root/.cache/pip/wheels/0c/47/80/8eb21098e22c19d60b1c14021ee67442b4ad2d7991fdad46ba
# Successfully built onnx-simplifier
# Installing collected packages: onnx, onnxruntime, onnxoptimizer, onnx-simplifier
# Successfully installed onnx-1.10.2 onnx-simplifier-0.3.6 onnxoptimizer-0.2.6 onnxruntime-1.9.0

# %%
# !python -m onnxsim nanodet.onnx nanodet.onnx
# Out:
# Simplifying...
# Checking 0/3...
# Checking 1/3...
# Checking 2/3...
# Ok!

# %% [markdown]
# # ONNXファイル情報確認(Check ONNX file information)

# %%
# !pip install onnxruntime
# Out:
# Requirement already satisfied: onnxruntime in /usr/local/lib/python3.7/dist-packages (1.9.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from onnxruntime) (3.17.3)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.7/dist-packages (from onnxruntime) (2.0)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.7/dist-packages (from onnxruntime) (1.19.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf->onnxruntime) (1.15.0)

# %%
import onnxruntime

onnx_session = onnxruntime.InferenceSession('nanodet.onnx')

# %%
input_detail = onnx_session.get_inputs()
output_detail = onnx_session.get_outputs()

input_name = onnx_session.get_inputs()[0].name
output_name = onnx_session.get_outputs()[0].name

print(len(input_detail), len(output_detail))
print('input_detail: ', input_detail[0])
print('output_detail: ', output_detail[0])
print('output_detail: ', output_detail[1])
print('output_detail: ', output_detail[2])
print('output_detail: ', output_detail[3])
print('output_detail: ', output_detail[4])
print('output_detail: ', output_detail[5])
# Out:
# 1 6
# input_detail:  NodeArg(name='input.1', type='tensor(float)', shape=[1, 3, 320, 320])
# output_detail:  NodeArg(name='cls_pred_stride_8', type='tensor(float)', shape=[1, 1600, 1])
# output_detail:  NodeArg(name='cls_pred_stride_16', type='tensor(float)', shape=[1, 400, 1])
# output_detail:  NodeArg(name='cls_pred_stride_32', type='tensor(float)', shape=[1, 100, 1])
# output_detail:  NodeArg(name='dis_pred_stride_8', type='tensor(float)', shape=[1, 1600, 32])
# output_detail:  NodeArg(name='dis_pred_stride_16', type='tensor(float)', shape=[1, 400, 32])
# output_detail:  NodeArg(name='dis_pred_stride_32', type='tensor(float)', shape=[1, 100, 32])

# %% [markdown]
# # 学習済ファイルダウンロード(Download Trained Model)

# %%
# !cp 'nanodet.onnx' 'workspace/nanodet_m'

# %%
# ダウンロードする
from google.colab import files

# !zip -r 'workspace.zip' 'workspace'
files.download('workspace.zip')
# Out:
#   adding: workspace/ (stored 0%)
#   adding: workspace/nanodet_m/ (stored 0%)
#   adding: workspace/nanodet_m/logs-2021-11-26-00-09-51/ (stored 0%)
#   adding: workspace/nanodet_m/logs-2021-11-26-00-09-51/Train_loss_lr_Train/ (stored 0%)
#   adding: workspace/nanodet_m/logs-2021-11-26-00-09-51/Train_loss_lr_Train/events.out.tfevents.1637885405.2716267a1b6a.177.1 (deflated 59%)
#   adding: workspace/nanodet_m/logs-2021-11-26-00-09-51/Val_metrics_mAP_Val/ (stored 0%)
#   adding: workspace/nanodet_m/logs-2021-11-26-00-09-51/Val_metrics_mAP_Val/events.out.tfevents.1637885421.2716267a1b6a.177.5 (deflated 60%)
#   adding: workspace/nanodet_m/logs-2021-11-26-00-09-51/train_cfg.yml (deflated 62%)
#   adding: workspace/nanodet_m/logs-2021-11-26-00-09-51/Val_metrics_AP_50_Val/ (stored 0%)
#   adding: workspace/nanodet_m/logs-2021-11-26-00-09-51/Val_metrics_AP_50_Val/events.out.tfevents.1637885421.2716267a1b6a.177.6 (deflated 62%)
#   adding: workspace/nanodet_m/logs-2021-11-26-00-09-51/events.out.tfevents.1637885405.2716267a1b6a.177.0 (deflated 5%)
#   adding: workspace/nanodet_m/logs-2021-11-26-00-09-51/Val_metrics_AP_small_Val/ (stored 0%)
#   adding: workspace/nanodet_m/logs-2021-11-26-00-09-51/Val_metrics_AP_small_Val/events.out.tfevents.1637885421.2716267a1b6a.177.8 (deflated 69%)
#   adding: workspace/nanodet_m/logs-2021-11-26-00-09-51/Train_loss_loss_qfl_Train/ (stored 0%)
#   adding: workspace/nanodet_m/logs-2021-11-26-00-09-51/Train_loss_loss_qfl_Train/events.out.tfevents.1637885407.2716267a1b6a.177.2 (deflated 62%)
#   adding: workspace/nanodet_m/logs-2021-11-26-00-09-51/Train_loss_loss_dfl_Train/ (stored 0%)
#   adding: workspace/nanodet_m/logs-2021-11-26-00-09-51/Train_loss_loss_dfl_Train/events.out.tfevents.1637885407.2716267a1b6a.177.4 (deflated 62%)
#   adding: workspace/nanodet_m/logs-2021-11-26-00-09-51/Train_loss_loss_bbox_Train/ (stored 0%)
#   adding: workspace/nanodet_m/logs-2021-11-26-00-09-51/Train_loss_loss_bbox_Train/events.out.tfevents.1637885407.2716267a1b6a.177.3 (deflated 63%)
#   adding: workspace/nanodet_m/logs-2021-11-26-00-09-51/Val_metrics_AP_75_Val/ (stored 0%)
#   adding: workspace/nanodet_m/logs-2021-11-26-00-09-51/Val_metrics_AP_75_Val/events.out.tfevents.1637885421.2716267a1b6a.177.7 (deflated 62%)
#   adding: workspace/nanodet_m/logs-2021-11-26-00-09-51/Val_metrics_AP_m_Val/ (stored 0%)
#   adding: workspace/nanodet_m/logs-2021-11-26-00-09-51/Val_metrics_AP_m_Val/events.out.tfevents.1637885421.2716267a1b6a.177.9 (deflated 61%)
#   adding: workspace/nanodet_m/logs-2021-11-26-00-09-51/logs.txt (deflated 76%)
#   adding: workspace/nanodet_m/logs-2021-11-26-00-09-51/Val_metrics_AP_l_Val/ (stored 0%)
#   adding: workspace/nanodet_m/logs-2021-11-26-00-09-51/Val_metrics_AP_l_Val/events.out.tfevents.1637885421.2716267a1b6a.177.10 (deflated 61%)
#   adding: workspace/nanodet_m/model_last.ckpt (deflated 8%)
#   adding: workspace/nanodet_m/results0.json (deflated 72%)
#   adding: workspace/nanodet_m/nanodet.onnx (deflated 7%)
#   adding: workspace/nanodet_m/model_best/ (stored 0%)
#   adding: workspace/nanodet_m/model_best/model_best.ckpt (deflated 8%)
#   adding: workspace/nanodet_m/model_best/eval_results.txt (deflated 62%)
#   adding: workspace/nanodet_m/logs.txt (stored 0%)
#   adding: workspace/nanodet_m/NanoDet/ (stored 0%)
#   adding: workspace/nanodet_m/NanoDet/2021-11-26-00-09-51/ (stored 0%)
#   adding: workspace/nanodet_m/NanoDet/2021-11-26-00-09-51/checkpoints/ (stored 0%)
#   adding: workspace/nanodet_m/NanoDet/2021-11-26-00-09-51/checkpoints/epoch=279-step=279.ckpt (deflated 8%)
