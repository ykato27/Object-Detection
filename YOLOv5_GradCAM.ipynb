# %% [markdown]
# <a href="https://colab.research.google.com/github/ykato27/Object-Detection/blob/main/YOLOv5_GradCAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # YOLO-V5 GRADCAM
# Visualizing yolov5's layers using GradCam algorithm
#
# ## Installation

# %%
# !pip install deep_utils
# !pip install -U opencv-python
# Out:
# Collecting deep_utils
#   Downloading deep_utils-0.8.19-py3-none-any.whl (164 kB)
#      |████████████████████████████████| 164 kB 6.0 MB/s
# Collecting requests>=2.27.1
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.5 MB/s
# Collecting numpy>=1.21.0
#   Downloading numpy-1.21.5-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 12.9 MB/s
# Requirement already satisfied: tqdm>=4.62.3 in /usr/local/lib/python3.7/dist-packages (from deep_utils) (4.62.3)
# Collecting opencv-python>=4.5.5.58
#   Downloading opencv_python-4.5.5.62-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.4 MB)
#      |████████████████████████████████| 60.4 MB 1.2 MB/s
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.27.1->deep_utils) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.27.1->deep_utils) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.27.1->deep_utils) (1.24.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.27.1->deep_utils) (2.0.11)
# Installing collected packages: numpy, requests, opencv-python, deep-utils
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.3.post1 requires numpy<1.20,>=1.16.0, but you have numpy 1.21.5 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed deep-utils-0.8.19 numpy-1.21.5 opencv-python-4.5.5.62 requests-2.27.1
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.5.5.62)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.21.5)

# %% [markdown]
# **Note**: After running the previous cell, restart the runtime.

# %% [markdown]
# ## Clone the project

# %%
# !git clone https://github.com/pooya-mohammadi/yolov5-gradcam
# Out:
# Cloning into 'yolov5-gradcam'...
# remote: Enumerating objects: 68, done.
# remote: Total 68 (delta 0), reused 0 (delta 0), pack-reused 68
# Unpacking objects: 100% (68/68), done.

# %% [markdown]
# # Infer

# %%
import os
os.chdir('/content/yolov5-gradcam')

# %%
# !python main.py --model-path yolov5s.pt --img-path images/eagle.jpg --output-dir out
# Out:
# /usr/local/lib/python3.7/dist-packages/deep_utils/vision/face_detection/ultralight/__init__.py:5: UserWarning:
# No module named 'deep_utils.vision.face_detection.ultralight.torch'. If you don't use UltralightTorchFaceDetector ignore this message.
#   'UltralightTorchFaceDetector')
# /usr/local/lib/python3.7/dist-packages/deep_utils/vision/face_detection/ultralight/__init__.py:8: UserWarning:
# No module named 'deep_utils.vision.face_detection.ultralight.tf'. If you don't use UltralightTFFaceDetector ignore this message.
#   'UltralightTFFaceDetector')
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# [INFO] Loading the model
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.0/yolov5s.pt to yolov5s.pt...
# 100% 14.0M/14.0M [00:00<00:00, 127MB/s]
#
# [INFO] Model is loaded
# [INFO] fetching names from coco file
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:1025: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# [INFO] saliency_map size : torch.Size([20, 20])
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:1025: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# [INFO] model-forward took:  0.3735 seconds
# [INFO] bird, model-backward took:  0.7171 seconds
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3509: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# total time: 1.1028
# Traceback (most recent call last):
#   File "main.py", line 89, in <module>
#     main()
#   File "main.py", line 77, in main
#     res_img, heat_map = get_res_img(bbox, mask, res_img)
#   File "main.py", line 31, in get_res_img
#     n_heatmat = (Box.fill_outer_box(heatmap, bbox) / 255).astype(np.float32)
#   File "/usr/local/lib/python3.7/dist-packages/deep_utils/utils/box_utils/boxes.py", line 430, in fill_outer_box
#     img = cv2.multiply(img, mask)
# NameError: name 'cv2' is not defined

# %%
# !python main.py --model-path yolov5s.pt --img-path images/cat-dog.jpg --output-dir out
# Out:
# /usr/local/lib/python3.7/dist-packages/deep_utils/vision/face_detection/ultralight/__init__.py:5: UserWarning:
# No module named 'deep_utils.vision.face_detection.ultralight.torch'. If you don't use UltralightTorchFaceDetector ignore this message.
#   'UltralightTorchFaceDetector')
# /usr/local/lib/python3.7/dist-packages/deep_utils/vision/face_detection/ultralight/__init__.py:8: UserWarning:
# No module named 'deep_utils.vision.face_detection.ultralight.tf'. If you don't use UltralightTFFaceDetector ignore this message.
#   'UltralightTFFaceDetector')
# [INFO] Loading the model
# [INFO] Model is loaded
# [INFO] fetching names from coco file
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:1025: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# [INFO] saliency_map size : torch.Size([20, 20])
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:1025: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# [INFO] model-forward took:  0.5712 seconds
# [INFO] dog, model-backward took:  0.9201 seconds
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3509: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# [INFO] cat, model-backward took:  0.8708 seconds
# total time: 2.3908
# Traceback (most recent call last):
#   File "main.py", line 89, in <module>
#     main()
#   File "main.py", line 77, in main
#     res_img, heat_map = get_res_img(bbox, mask, res_img)
#   File "main.py", line 31, in get_res_img
#     n_heatmat = (Box.fill_outer_box(heatmap, bbox) / 255).astype(np.float32)
#   File "/usr/local/lib/python3.7/dist-packages/deep_utils/utils/box_utils/boxes.py", line 430, in fill_outer_box
#     img = cv2.multiply(img, mask)
# NameError: name 'cv2' is not defined

# %%
from PIL import Image
Image.open("outputs/eagle-res.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x448 at 0x7F33CF43FF10>

# %%
from PIL import Image
Image.open("outputs/cat-dog-res.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x640 at 0x7F33CF3C6DD0>
